# %%
import pandas as pd
import numpy as np
import os
import sys
import seaborn as sns
from scipy.stats import spearmanr, linregress
import matplotlib.pyplot as plt
import EpiClockNBL.src.util as pc_util
nbl_consts = pc_util.consts
import EpiClockNBL.Select_fCpGs.util as local_util
import EpiClockNBL.src.maxima as maxima

# %%
proj_dir = os.path.join(nbl_consts['official_indir'], 'TARGET')

# %%
figure_outdir = 'figures'
os.makedirs(figure_outdir, exist_ok=True)

# %%
clinical = pd.read_table(os.path.join(proj_dir, 'clinical.annotated.tsv'), index_col=0)

# %%
## Configure graph
sf = 1
figsize = np.array([7, 6])
sns.set(rc={"savefig.bbox":'tight', 'axes.linewidth':sf}, font_scale=1, style='ticks')

clinical.name = 'TARGET-NBL'

# %% [markdown]
# # Analysis

# %%
use_samples = clinical.index[clinical['age_at_diagnosis'] < 365].values
pc_util.saveCorrelationPlot(clinical, var_y='age_at_diagnosis', restrict=False,
                            var_x='c_beta', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['age_at_diagnosis', 'c_beta']]))
print(linregress(clinical.loc[use_samples, 'age_at_diagnosis'], clinical.loc[use_samples, 'c_beta']))
# Out:
# n = 31
# SignificanceResult(statistic=np.float64(-0.02762653817009375), pvalue=np.float64(0.8827177018028726))
# LinregressResult(slope=np.float64(-7.435472286308807e-05), intercept=np.float64(0.799975381432541), rvalue=np.float64(-0.23213710896034495), pvalue=np.float64(0.20889068778102693), stderr=np.float64(5.7854393820392664e-05), intercept_stderr=np.float64(0.00884968497943212))

# %%
use_samples = clinical.index[clinical['age_at_diagnosis'] < 365].values
pc_util.saveCorrelationPlot(clinical, var_y='age_at_diagnosis', restrict=False,
                            var_x='c_beta_traditional', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['age_at_diagnosis', 'c_beta']]))
print(linregress(clinical.loc[use_samples, 'age_at_diagnosis'], clinical.loc[use_samples, 'c_beta']))
# Out:
# n = 31
# SignificanceResult(statistic=np.float64(-0.02762653817009375), pvalue=np.float64(0.8827177018028726))
# LinregressResult(slope=np.float64(-7.435472286308807e-05), intercept=np.float64(0.799975381432541), rvalue=np.float64(-0.23213710896034495), pvalue=np.float64(0.20889068778102693), stderr=np.float64(5.7854393820392664e-05), intercept_stderr=np.float64(0.00884968497943212))

# %%
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=True,
                           var_x='c_beta',
                             outfile=False,
                           text_x=0.85, text_y=7,
                           figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=1,
                           color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                          )

print(spearmanr(clinical[['Age', 'c_beta']]))
print(linregress(clinical['Age'], clinical['c_beta']))
# Out:
# SignificanceResult(statistic=np.float64(-0.22611287083201206), pvalue=np.float64(0.005243480265780092))
# LinregressResult(slope=np.float64(-0.00387824705821125), intercept=np.float64(0.7737624916316471), rvalue=np.float64(-0.22815244015844605), pvalue=np.float64(0.004839217292704344), stderr=np.float64(0.0013558421311511539), intercept_stderr=np.float64(0.0059689260972826))

# %%
use_samples = clinical.index[clinical['Age'] < 2].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta']))
# Out:
# n = 52
# SignificanceResult(statistic=np.float64(-0.35100002206481895), pvalue=np.float64(0.01073184335506933))
# LinregressResult(slope=np.float64(-0.02716884450905352), intercept=np.float64(0.8000003993496457), rvalue=np.float64(-0.43995829796338143), pvalue=np.float64(0.001099876886376511), stderr=np.float64(0.007842595099693409), intercept_stderr=np.float64(0.008980959288685846))

# %%
use_samples = clinical.index[clinical['Age'] < 1].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta']))
# Out:
# n = 31
# SignificanceResult(statistic=np.float64(-0.02762653817009375), pvalue=np.float64(0.8827177018028726))
# LinregressResult(slope=np.float64(-0.02713947384502715), intercept=np.float64(0.7999753814325411), rvalue=np.float64(-0.23213710896034495), pvalue=np.float64(0.20889068778102693), stderr=np.float64(0.021116853744443324), intercept_stderr=np.float64(0.008849684979432122))

# %%
use_samples = clinical.index[clinical['Age'] < 0.5].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta']))
# Out:
# n = 22
# SignificanceResult(statistic=np.float64(0.3259887525916529), pvalue=np.float64(0.13872271612603626))
# LinregressResult(slope=np.float64(0.054887405697184956), intercept=np.float64(0.7902139610254966), rvalue=np.float64(0.16739455833650574), pvalue=np.float64(0.4565151165721427), stderr=np.float64(0.07228444070477373), intercept_stderr=np.float64(0.010490915310302959))

# %%
use_samples = clinical.index[clinical['Age'] < 0.25].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.2,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

from scipy.stats import spearmanr, linregress
print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta']))
# Out:
# n = 21
# SignificanceResult(statistic=np.float64(0.3918129482096611), pvalue=np.float64(0.07898845589686633))
# LinregressResult(slope=np.float64(0.17021988158376639), intercept=np.float64(0.7804969028362904), rvalue=np.float64(0.36857137326587014), pvalue=np.float64(0.10016425294175), stderr=np.float64(0.09849353894350732), intercept_stderr=np.float64(0.011664150850468001))

# %% [markdown]
# # Analysis with traditionally picked sites

# %%
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=True,
                           var_x='c_beta_traditional',
                             outfile=False,
                           text_x=0.85, text_y=7,
                           figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=10,
                           color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                          )

print(spearmanr(clinical[['Age', 'c_beta_traditional']]))
print(linregress(clinical['Age'], clinical['c_beta_traditional']))
# Out:
# SignificanceResult(statistic=np.float64(-0.23014739520693872), pvalue=np.float64(0.00447103530624269))
# LinregressResult(slope=np.float64(-0.003463076052459793), intercept=np.float64(0.729228796445451), rvalue=np.float64(-0.2052370603771895), pvalue=np.float64(0.011471146523012647), stderr=np.float64(0.0013529076479756525), intercept_stderr=np.float64(0.005956007400624741))

# %%
use_samples = clinical.index[clinical['Age'] < 2].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta_traditional', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta_traditional']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta_traditional']))
# Out:
# n = 52
# SignificanceResult(statistic=np.float64(-0.3486947433988617), pvalue=np.float64(0.011295747471385764))
# LinregressResult(slope=np.float64(-0.02672148426282471), intercept=np.float64(0.7578500806765454), rvalue=np.float64(-0.42272223309224677), pvalue=np.float64(0.0017964861903103032), stderr=np.float64(0.008101640355521415), intercept_stderr=np.float64(0.009277605343587939))

# %%
use_samples = clinical.index[clinical['Age'] < 1].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta_traditional', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta_traditional']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta_traditional']))
# Out:
# n = 31
# SignificanceResult(statistic=np.float64(-0.005242992645419253), pvalue=np.float64(0.9776683191932287))
# LinregressResult(slope=np.float64(-0.026197083521450348), intercept=np.float64(0.7576520322096706), rvalue=np.float64(-0.21087678811947003), pvalue=np.float64(0.254817588271847), stderr=np.float64(0.022550052313762777), intercept_stderr=np.float64(0.009450312137480581))

# %%
use_samples = clinical.index[clinical['Age'] < 0.5].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta_traditional', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.5,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta_traditional']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta_traditional']))
# Out:
# n = 22
# SignificanceResult(statistic=np.float64(0.31525428760163315), pvalue=np.float64(0.1529740426635859))
# LinregressResult(slope=np.float64(0.06121544473495306), intercept=np.float64(0.7471739565346207), rvalue=np.float64(0.16697938471608814), pvalue=np.float64(0.4576486904513464), stderr=np.float64(0.08082442459075517), intercept_stderr=np.float64(0.011730355594071614))

# %%
use_samples = clinical.index[clinical['Age'] < 0.25].values
pc_util.saveCorrelationPlot(clinical, var_y='Age', restrict=False,
                            var_x='c_beta_traditional', use_samples=use_samples,
                            outfile=False,
                            text_x=0.85, text_y=0.2,
                            figsize=figsize * 0.9, labelfontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, s=40,
                            color=nbl_consts['palette_jco'][0], line_kws={'linewidth':1 * sf}
                           )
print(f'n = {use_samples.shape[0]}')

from scipy.stats import spearmanr, linregress
print(spearmanr(clinical.loc[use_samples, ['Age', 'c_beta_traditional']]))
print(linregress(clinical.loc[use_samples, 'Age'], clinical.loc[use_samples, 'c_beta_traditional']))
# Out:
# n = 21
# SignificanceResult(statistic=np.float64(0.37751794844081776), pvalue=np.float64(0.09157147788369008))
# LinregressResult(slope=np.float64(0.16500514551025733), intercept=np.float64(0.7384294068826585), rvalue=np.float64(0.31796966240927127), pvalue=np.float64(0.16012100587835545), stderr=np.float64(0.11287286651515117), intercept_stderr=np.float64(0.013367030528902014))

# %%
beta_values_Clock_CpGs_traditional = pd.read_table(os.path.join(proj_dir, f'NBL.methyl.traditional_sites.tsv'), index_col=0)

# %%
n_samps = 30

c_beta_traditional = 1 - beta_values_Clock_CpGs_traditional.var(axis=0)

# Plot Clock beta values youngest tumors and save plot
youngest = c_beta_traditional.sort_values().index[:n_samps]
pc_util.plotTumorWise(
    beta_values_Clock_CpGs_traditional,
    data_obj = "beta_decomp",
    n_samps=n_samps, ncols=3,
    choose_random=False,
    sample_list=youngest,
    figsize=figsize * [2, 4.5/18 * n_samps], text_fontsize=nbl_consts['labelfontsize'], ticksfontsize=nbl_consts['ticksfontsize'], opacity=nbl_consts['opacity'], sf=1,
    tight_layout_pad=6, bins=40,
    suptitle='Highest $c_β$ value',
    outfile=False
)
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:486: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
