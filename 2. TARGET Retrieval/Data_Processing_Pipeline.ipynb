# %%
from EpiClockNBL.data_processing import TARGET_clinical
from EpiClockNBL.analysis import clinical_table
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
TARGET_clinical.pipeline()
# Out:
# Running TARGET data processing pipeline with verbose=True.
# ####################################################################################################
# ####################################################################################################
#
# Importing DNA methylation and clinical data... DONE
#
# Calculating LUMP purity values... DONE
#
# Processing clinical data...
# primary_diagnosis
# Neuroblastoma, NOS      186
# Ganglioneuroblastoma     27
# Name: count, dtype: int64
# 27 tumors were ganglioneuroblastomas
# 29 neuroblastoma tumors had LUMP < 0.7
#
# DONE
#
# Retrieving and joining in MYCN amplication data from supplementary clinical data... DONE
#
# Retrieving and joining in follow-up (survival) data from supplementary clinical data... DONE
#
# Save processed clinical data... Current output matches existing file.
# DONE

# %%
clinical_table.pipeline()
print('Saved summary table')
# Out:
# Saved summary table
