# %%
from EpiClockNBL.process_supplementary_data import process_series_matrix, process_data
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
process_series_matrix.pipeline()
# Out:
# Running process_series_matrix pipeline with verbose=True.
# ####################################################################################################
# ####################################################################################################
# Loading and processing series matrix file...
# 100%|██████████| 382261/382261 [00:18<00:00, 20529.31it/s]
# Read 36 lines from header, 382,183 lines from DNAm data section.
#
# DONE
# Writing header and DNAm data to files... DONE

# %%
process_data.pipeline()
# Out:
# Running process_data pipeline with verbose=True.
# ####################################################################################################
# ####################################################################################################
# Loading beta values... DONE
# Select intersecting Clock CpGs of beta values... DONE
# Saving Clock beta values file...
#
# Current output matches existing file.
# C:\Users\DanMonyak\Box\PROJECT 06023□ MolClocks\Neuroblastoma_Paper\Datasets\Henrich\Henrich.methyl.TARGET_Clock_sites.tsv
#
# DONE
# Loading and processing sample annotations... DONE
#
# Save processed clinical data... Current output matches existing file.
# C:\Users\DanMonyak\Box\PROJECT 06023□ MolClocks\Neuroblastoma_Paper\Datasets\Henrich\clinical.processed.tsv
# DONE
