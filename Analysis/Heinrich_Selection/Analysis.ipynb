# %%
import pandas as pd
import numpy as np
import os
import sys
import seaborn as sns 
import matplotlib.pyplot as plt
import EpiClockNBL.src.util as pc_util
nbl_consts = pc_util.consts
import EpiClockNBL.Select_fCpGs.util as local_util
import EpiClockNBL.src.maxima as maxima

# %%
proj_dir = os.path.join(nbl_consts['official_indir'], 'Heinrich')

# %%
sample_annotations = pd.read_table(os.path.join(proj_dir, 'sample_annotations_clean.txt'), index_col='Sample_geo_accession')
c_beta = pd.read_table(os.path.join('../outputs', 'Heinrich.c_beta.txt'), index_col=0, header=None).squeeze('columns')
sample_annotations['c_beta'] = c_beta

# %%
## Configure graph
sf = 1
figsize = np.array([7, 6])
sns.set(rc={"savefig.bbox":'tight', 'axes.linewidth':sf}, font_scale=1, style='ticks')

sample_annotations.name = 'NB'

# %%
sample_annotations.iloc[0]
# Out:
# Unnamed: 0                                   genomic DNA from neuroblastoma tumor 1
# Sample_status                                                 Public on Sep 08 2016
# Sample_submission_date                                                  Sep 28 2015
# Sample_last_update_date                                                 Sep 08 2016
# Sample_type                                                                 genomic
# Sample_channel_count                                                              1
# Sample_source_name_ch1                                              neuroblastoma 1
# Sample_organism_ch1                                                    Homo sapiens
# inss stage                                                                        4
# current risk category                                             intermediate-risk
# age at diagnosis                                                         <1.5 years
# ...

# %% [markdown]
# # Box plots

# %%
pc_util.saveBoxPlotNew(sample_annotations, 'inss stage', restrict=False,
                   var_y='c_beta', outfile=False, title=False, signif_bar_heights = 0.02,
                   palette=nbl_consts['palette_jco'], xlabel='inss stage',
                   figsize=np.array([9, 7]), labelfontsize=nbl_consts['labelfontsize'] * 0.9, ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, linewidth=nbl_consts['linewidth'], fliersize=nbl_consts['fliersize'])
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: UserWarning: The palette list has more values (10) than needed (6), which may not be intended.
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# <Axes: xlabel='inss stage', ylabel='$c_β$'>

# %%
cat_order = ["low-risk", "intermediate-risk", "high-risk"]

pc_util.saveBoxPlotNew(sample_annotations, 'current risk category', restrict=False,
                   var_y='c_beta', outfile=False, title=False, use_groups = cat_order, signif_bar_heights = 0.01,
                   palette=nbl_consts['palette_jco'], xlabel='current risk category',
                   figsize=np.array([7, 7]), labelfontsize=nbl_consts['labelfontsize'] * 0.9, ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, linewidth=nbl_consts['linewidth'], fliersize=nbl_consts['fliersize'])
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# <Axes: xlabel='current risk category', ylabel='$c_β$'>

# %%
pc_util.saveBoxPlotNew(sample_annotations, 'mycn status', restrict=False,
                   var_y='c_beta', outfile=False, title=False, signif_bar_heights = 0.01,
                   palette=nbl_consts['palette_jco'], xlabel='',
                   figsize=np.array([8, 5]), labelfontsize=nbl_consts['labelfontsize'] * 0.9, ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, linewidth=nbl_consts['linewidth'], fliersize=nbl_consts['fliersize'])
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# <Axes: ylabel='$c_β$'>

# %%
pc_util.saveBoxPlotNew(sample_annotations, '1p status', restrict=False,
                   var_y='c_beta', outfile=False, title=False, signif_bar_heights = 0.015,
                   palette=nbl_consts['palette_jco'], xlabel='',
                   figsize=np.array([9, 7]), labelfontsize=nbl_consts['labelfontsize'] * 0.9, ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, linewidth=nbl_consts['linewidth'], fliersize=nbl_consts['fliersize'])
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# <Axes: ylabel='$c_β$'>

# %%
pc_util.saveBoxPlotNew(sample_annotations, '11q status', restrict=False,
                   var_y='c_beta', outfile=False, title=False, signif_bar_heights = 0.015,
                   palette=nbl_consts['palette_jco'], xlabel='',
                   figsize=np.array([11, 7]), labelfontsize=nbl_consts['labelfontsize'] * 0.9, ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, linewidth=nbl_consts['linewidth'], fliersize=nbl_consts['fliersize'])
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# <Axes: ylabel='$c_β$'>

# %%
pc_util.saveBoxPlotNew(sample_annotations, '17q status', restrict=False,
                   var_y='c_beta', outfile=False, title=False, signif_bar_heights = 0.015,
                   palette=nbl_consts['palette_jco'], xlabel='',
                   figsize=np.array([11, 7]), labelfontsize=nbl_consts['labelfontsize'] * 0.9, ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, linewidth=nbl_consts['linewidth'], fliersize=nbl_consts['fliersize'])
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# <Axes: ylabel='$c_β$'>

# %%
pc_util.saveBoxPlotNew(sample_annotations, 'age at diagnosis', restrict=False,
                   var_y='c_beta', outfile=False, title=False, signif_bar_heights = 0.01,
                   palette=nbl_consts['palette_jco'], xlabel='age at diagnosis',
                   figsize=np.array([6, 5]), labelfontsize=nbl_consts['labelfontsize'] * 0.9, ticksfontsize=nbl_consts['ticksfontsize'], sf=sf, linewidth=nbl_consts['linewidth'], fliersize=nbl_consts['fliersize'])
# Out:
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# /Users/grahamgumbert/Documents/GitHub/EpiClockNBL/src/util.py:154: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.boxplot(ax=ax, data=plot_data, x=var_cat, y=var_y,
# <Axes: xlabel='age at diagnosis', ylabel='$c_β$'>

# %% [markdown]
# # Beta values

# %%
beta_values_Clock = pd.read_table(os.path.join(proj_dir, 'Henrich.methyl.antiNonIterClustNotStuck_sites.tsv'), index_col=0)

# %%
sns.histplot(beta_values_Clock['GSM1896914'], bins=50)
# Out:
# <Axes: xlabel='GSM1896914', ylabel='Count'>

# %%
samp = sample_annotations['c_beta'].sort_values().index.values[0]
sns.histplot(beta_values_Clock[samp], bins=25)
# Out:
# <Axes: xlabel='GSM1896914', ylabel='Count'>

# %%
sample_annotations['c_beta'].sort_values()
# Out:
# Sample_geo_accession
# GSM1896914    0.733275
# GSM1896984    0.765711
# GSM1896933    0.776585
# GSM1896989    0.776591
# GSM1897022    0.781289
#                 ...
# GSM1896956    0.841172
# GSM1896931    0.841904
# GSM1896997    0.843322
# GSM1896940    0.845287
# GSM1896985    0.847363
# Name: c_beta, Length: 105, dtype: float64

# %%
samp = sample_annotations['c_beta'].sort_values().index.values[-4]
sns.histplot(beta_values_Clock[samp], bins=25)
# Out:
# <Axes: xlabel='GSM1896931', ylabel='Count'>

# %%
samp = sample_annotations['c_beta'].sort_values().index.values[4]
sns.histplot(beta_values_Clock[samp], bins=50)
# Out:
# <Axes: xlabel='GSM1897022', ylabel='Count'>

# %%
sample_annotations.groupby('mycn status')['age at diagnosis'].value_counts().unstack()
# Out:
# age at diagnosis   <1.5 years  >=1.5 years
# mycn status
# MYCN-amplified             12           21
# MYCN-nonamplified          50           22

# %%
sample_annotations.groupby('current risk category')['age at diagnosis'].value_counts().unstack()
# Out:
# age at diagnosis       <1.5 years  >=1.5 years
# current risk category
# high-risk                      15           41
# intermediate-risk               8            1
# low-risk                       39            1

# %%
diff_list = []
for site in beta_values_Clock.index:
# site = beta_values_Clock.index[0]

    df = pd.concat([sample_annotations['age at diagnosis'], beta_values_Clock.loc[site]], axis=1)
    difference = df.groupby('age at diagnosis')[site].mean()
    diff_list.append(np.abs(difference['>=1.5 years'] - difference['<1.5 years']))

# %%
plt.hist(diff_list)
# Out:
# (array([179., 172., 174., 170., 136.,  74.,  49.,  27.,  14.,   5.]),
#  array([7.63113247e-05, 1.66882636e-02, 3.33002159e-02, 4.99121682e-02,
#         6.65241205e-02, 8.31360728e-02, 9.97480251e-02, 1.16359977e-01,
#         1.32971930e-01, 1.49583882e-01, 1.66195834e-01]),
#  <BarContainer object of 10 artists>)
