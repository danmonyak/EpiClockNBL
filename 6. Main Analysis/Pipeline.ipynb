# %%
from EpiClockNBL.analysis import post_gmm_data_processing
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
post_gmm_data_processing.pipeline()
# Out:
# Running post_gmm_data_processing pipeline with verbose=True.
# ####################################################################################################
# ####################################################################################################
# Loading clinical tables... DONE
# Loading GMM results... DONE
# Adding mitotic age estimate to clinical tables... DONE
# Saving clinical tables...
#
# Current output matches existing file.
# C:\Users\DanMonyak\Box\PROJECT 06023□ MolClocks\Neuroblastoma_Paper\Datasets\TARGET\clinical.processed.withAges.tsv
# Current output matches existing file.
# C:\Users\DanMonyak\Box\PROJECT 06023□ MolClocks\Neuroblastoma_Paper\Datasets\Henrich\clinical.processed.withAges.tsv
#
# DONE
